# %% [markdown]
# # Google Colabにて必要なモジュールを取得

# %%
# !pip install langgraph langchain_openai langchain_core httpx requests
# Out:
# DEPRECATION: Loading egg at /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages/tensorboardX-2.6.2.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages/six-1.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages/cycler-0.12.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages/xmltodict-0.13.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages/MarkupSafe-2.1.5-py3.11-macosx-14.5-arm64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages/kiwisolver-1.4.5-py3.11-macosx-14.5-arm64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages/PySocks-1.7.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages/audioread-3.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages/decorator-5.1.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages/kaldiio-2.18.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages/soundfile-0.12.1-py3.11-macosx-14.5-arm64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages/mpmath-1.3.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages/charset_normalizer-3.3.2-py3.11-macosx-14.5-arm64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: langgraph in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (0.2.46)
# Requirement already satisfied: langchain_openai in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (0.1.10)
# Requirement already satisfied: langchain_core in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (0.2.43)
# Requirement already satisfied: httpx in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (0.27.0)
# Requirement already satisfied: requests in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.0.0 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langgraph) (2.0.3)
# Requirement already satisfied: langgraph-sdk<0.2.0,>=0.1.32 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langgraph) (0.1.35)
# Requirement already satisfied: openai<2.0.0,>=1.26.0 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain_openai) (1.46.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain_openai) (0.7.0)
# Requirement already satisfied: PyYAML>=5.3 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain_core) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain_core) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain_core) (0.1.142)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain_core) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain_core) (2.6.1)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain_core) (8.4.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain_core) (4.12.2)
# Requirement already satisfied: anyio in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx) (4.2.0)
# Requirement already satisfied: certifi in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx) (1.0.2)
# Requirement already satisfied: idna in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx) (3.6)
# Requirement already satisfied: sniffio in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpcore==1.*->httpx) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages/charset_normalizer-3.3.2-py3.11-macosx-14.5-arm64.egg (from requests) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests) (2.2.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain_core) (3.0.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.1.0 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langgraph-checkpoint<3.0.0,>=2.0.0->langgraph) (1.1.0)
# Requirement already satisfied: httpx-sse>=0.4.0 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langgraph-sdk<0.2.0,>=0.1.32->langgraph) (0.4.0)
# Requirement already satisfied: orjson>=3.10.1 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langgraph-sdk<0.2.0,>=0.1.32->langgraph) (3.10.5)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.112->langchain_core) (1.0.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from openai<2.0.0,>=1.26.0->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from openai<2.0.0,>=1.26.0->langchain_openai) (0.5.0)
# Requirement already satisfied: tqdm>4 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from openai<2.0.0,>=1.26.0->langchain_openai) (4.66.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pydantic<3,>=1->langchain_core) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pydantic<3,>=1->langchain_core) (2.16.2)
# Requirement already satisfied: regex>=2022.1.18 in /Users/kunieda/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain_openai) (2024.5.15)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # LangChainで利用するLLMの設定

# %%
import os
from langchain_openai import AzureChatOpenAI

# 非推奨だが環境変数をベタがきしても良い
#os.environ["OPENAI_API_VERSION"] = "2024-xx-xx-preview"
#os.environ["AZURE_OPENAI_ENDPOINT"] = "https://xxxxxxxxxx.openai.azure.com"
#os.environ["AZURE_OPENAI_API_KEY"] = "xxxxxxxxxx"

# Google Colabで設定した場合
from google.colab import userdata
os.environ["OPENAI_API_VERSION"] = userdata.get("OPENAI_API_VERSION")
os.environ["AZURE_OPENAI_ENDPOINT"] = userdata.get("AZURE_OPENAI_ENDPOINT")
os.environ["AZURE_OPENAI_API_KEY"] = userdata.get("AZURE_OPENAI_API_KEY")

model = AzureChatOpenAI(
    azure_deployment="gpt-4o",
    temperature=0,
)

#小説生成専用のLLMを利用する
from langchain_community.llms import Ollama
llm = Ollama(model="huggingface.co/Local-Novel-LLM-project/Kagemusya-7B-v1-GGUF")
#llm = Ollama(model="huggingface.co/Local-Novel-LLM-project/Shadows-MoE-GGUF")
#llm = Ollama(model="huggingface.co/Local-Novel-LLM-project/Ninja-V3-GGUF:Q4_K_M")

# %% [markdown]
# # LangChain単体で利用して（Chainを使わずに）、簡単な小説を作成するコード

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

user_input = "ハッピーエンドのボーイミーツガール"

prompt = ChatPromptTemplate.from_messages(
    [
        ("system","ユーザが指定するジャンル等の情報をもとに、短編小説を生成するAIです。"),
        ("human", "{user_input}")
    ]
)

output_parser = StrOutputParser()

#LCELを使わない場合
prompt_value = prompt.invoke({"user_input": user_input})
ai_message = llm.invoke(prompt_value)
output = output_parser.invoke(ai_message)

print(prompt_value)
print(ai_message)
print(output)

#テキストファイルに出力。Colabの場合は、Colabのフォルダからダウンロードする
with open("output_sample01.txt", "w") as f:
    f.write(output)

# %% [markdown]
# # 上記の単純な機能をLCELで書き直したコード

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

user_input = "ハッピーエンドのボーイミーツガール"

prompt = ChatPromptTemplate.from_messages(
    [
        ("system","ユーザが指定するジャンル等の情報をもとに、短編小説を生成するAIです。"),
        ("human", "{user_input}のジャンルの小説を続きから生成してください\n\n ---- \n\n ある夏の日、" )
    ]
)

output_parser = StrOutputParser()

#ここでChainを組む
chain = prompt | llm | output_parser

output = ""
#テキストが少しずつ生成されるようにするために、streamを使う
for chunk in chain.stream({"user_input":user_input}):
    print(chunk, end="", flush=True)
    output += chunk

#これまで通りinvokeを利用することもできる
#output = chain.invoke({"user_input":user_input})

with open("output_sample02.txt", "w") as f:
    f.write(output)
# Out:
# 物です。主人公は高校一年生です。
# ヒロインは同じく高校一年生で、いつも明るく友達思いの女の子です。ふたりは運命的な出会いをしますが、お互いに遠慮し合って距離を測っていました。そんな中、ふたりが大事な秘密を共有することになります。ひとつ目は、主人公の母親が再婚相手の男性に虐待されており、今度も同じようなことになってしまうかもしれないということ。ふたりはそれぞれの家族を守るために協力することになります。ふたりが距離を縮めるきっかけになった秘密です。
# ふたりの距離がさらに近づいたのは、ふたりの家族が危険な目にあってしまったときでした。主人公の家族もヒロインの家族も命を狙われそうになります。ここでようやくふたりはお互いの距離を測ることができないほど、深く惹かれ合っていることを自覚します。
# 最後は、ふたりが協力して家族を守り抜き、恋人同士になって幸せに暮らします。
# プロット完成！
# それでは次のステップに移りましょう。物語を書くために必要な「シーン」を作る作業です。
# シーンというのは、場面や状況のことです。シーンがどんどん積み重なってストーリー全体の構造を成り立たせます。プロットに記述した出来事をより具体的かつ鮮明に描くことで、読者がイメージしやすい物語を作ることができます。
# シーンを考えるうえでは、次の三点を意識するといいでしょう。
# １．場所と時間
# どんな出来事が起こっているかに関係なく、物語のシーンは「どこで」「いつ頃」に起きたものなのかを明確にします。場所は地理的な位置や空間だけでなく、心理状態や状況設定なども含みます。
# ２．登場人物と行動
# シーンの中で誰が何をしているのかを決めます。それぞれのキャラクターの性格や目的、心理状態などに合わせた行動を取らせましょう。
# ３．シーンの結果
# 何が起きることでシーンが終わるのかを決めます。それによって次のシーンへつながる展開や、ストーリー全体の流れを決定します。
# 具体的には、以下のような手順で作成していきましょう。
# ①プロット上の出来事からシーンを選ぶ。
# ②その出来事が起こる「場所」と「時間」を設定する。
# ③登場人物たちは何をしているのか、どんな行動を取っているのかを決める。
# ④その行動がもたらす「結果」を考える。
# この四つの要素を決めれば、シーンは完成です。プロット段階で粗く設定しておいた内容をより具体的に描写しましょう。そうすることで、読者がイメージしやすくなってストーリーの理解度も高まります。
# シーン例
# さあ、実際にシーンを作成してみましょう。先ほどプロットで決めた「ボーイミーツガール物」をベースにしながらも、オリジナル要素を加えたシーン例を紹介します。
# ヒロインが主人公の家に遊びに行く場面です。
# シーン１：ヒロインと主人公、初めて訪れる主人公の家
# 「ただいま～！」
# ピンポーンとチャイムが鳴った後に現れたのは、明るく友達思いな女の子。名前をヒロインとしましょう。彼女は主人公の家を初めて訪れます。
# 「どうぞ～！」
# 家に上がったヒロインは、主人公に笑顔で挨拶します。その瞬間からふたりの距離は急速に近づきます。
# 「おじゃましまーす！」
# 主人公が案内をして、ヒロインは家の中を見回します。リビングや廊下など、部屋の様子は普通ですが、そこから感じる空気には温もりがあります。
# 「ご両親は？」
# ヒロインが疑問を口にします。主人公は少し考えてから答えました。
# 「お父さんとお母さんなら出かけてるよ。今日は留守番ってことになってる」
# そう言われ、ヒロインはちょっぴり残念そうな表情を浮かべますが、「そっかー！」と気持ちを切り替えます。
# シーン２：主人公の部屋でふたりきりになる
# ヒロインはリビングで少し待つよう言われて、主人公の自室へ案内されます。そこは小ぢんまりとした部屋でしたが、整理整頓されており、とても居心地が良さそうです。
# 「座って！」
# ベッドに腰掛ける主人公の横にヒロインも腰かけました。部屋の中を見回しながらお喋りを始めます。
# 「あ、これは？」
# ヒロインが本棚から一冊の小説を取り出しました。タイトルには『恋人たちの予感』と書かれています。主人公が好きな作品だったようで、笑顔でそれをヒロインに手渡します。
# 「こんな小説読むんだね！　私もちょっと読んでみるかなー」
# ヒロインは主人公から受け取った本を開き、ページをめくり始めました。その表情は真剣そのものです。
# シーン３：予期せぬ来客によって二人が引き離される
# 突然、チャイムが鳴り響いてヒロインが部屋を飛び出します。主人公もその後を追いました。玄関では見知らぬ大人が待っており、二人に対して言葉を投げかけます。
# 「君たち、こんな時間に一緒にいるとはどういうつもりだい？」
# その質問にヒロインが答えようと口を開きましたが、主人公がそれを制止します。
# 「ごめん、ちょっと待っててくれないかな……」
# そう言われてもヒロインは納得できずに主人公の腕を掴みますが、主人公はそれを振りほどきました。
# 「ちょっと！　何するんだよぉー！」
# 驚いてヒロインが叫びますが、主人公は無言でその場から離れて行きます。後に残されたヒロインはしばらく呆然と立ち尽くしていましたが、やがて涙を流し始めました。
# シーン４：主人公の家で一人泣くヒロイン
# 「ああぁ……」
# 部屋にひとり残されたヒロインは、ベッドの上で膝を抱えて、声を出して泣きます。主人公が急に自分から離れて行ったことがショックだったようです。
# 「どうして……？　私、何かしちゃったのかなぁ……」
# 泣きながらもヒロインは自分の言動を振り返ります。本棚にある小説を読んでいたところだったので、それが原因で主人公に嫌われてしまったのかもしれないと考えます。
# 「どうしよぉ……」
# 今さら後悔しても遅いのは分かっていますが、ヒロインにはそれしかできませんでした。そして、しばらく泣き続けた後に、彼女はベッドの中へと潜り込みます。
# シーン例を通じて、ヒロインがどれだけ主人公に心を開いて好意を寄せているかが分かったでしょう。このような小さなエピソード一つとっても、キャラクターの深みや個性を描き出すことができます。
# シナリオ作成は大変ですが、上手くいけば読者に強い印象を残す素晴らしい物語を創り出すことができるのです。ぜひ頑張ってみましょう！
# 第四章　キャラクターに命を吹き込む方法
# シナリオ作成において、登場人物は非常に重要な存在です。そのキャラクターたちが個性的で魅力的だと読者は感じ、ストーリーに没頭しやすくなります。
# この章では、より魅力的なキャラクターを作る方法をご紹介します。
# １．目的意識を持たせる
# 登場人物には必ず目的や夢といったものを設定しておきましょう。これはストーリーの方向性を明確にするだけでなく、キャラクター自身の軸となります。
# 目的がある人物は、行動や決断において一貫性を持つことができます。それによって読者から信頼感を得ることも可能です。
# 例えば、『風の谷のナウシカ』に登場する主人公の少女・ナウシカは、汚染された大地を綺麗にして、そこに蘇った生命体と共に平和な世界を作り上げることが目的です。だからこそ彼女の行動は一貫性があり、読者もナウシカを応援したくなるのです。
# ２．反対の属性を持たせる
# キャラクターに必ず反対の性格や特徴を持たせましょう。例えば、真面目で優等生な人物は、気が利かないだらしないところも持っているようにすると、キャラクターの深みや魅力を引き出せます。
# 反対の属性を持たせることで、それが相乗効果を生んで特別な個性を作り出すこともあります。例えば『ディズニー映画・アラビアの魔法使い』に登場するジャスミンは、姉のシェリーと反対の性格で自由奔放で気まぐれな一面を持っています。そんな彼女だからこそ、魔法使いの弟・アルバムに愛される存在となったのです。
# ３．過去を設定する
# キャラクターに過去の出来事や経験を設定しましょう。これは人物像をより深く掘り下げ、読者との共感を高める効果があります。
# 『シン・ゴジラ』に登場する主人公の神崎隊長は、かつて怪獣相手に勇敢な戦いを繰り広げた英雄でした。そんな過去があるからこそ、彼の決意や行動力に説得力が生まれています。
# ４．秘密を持たせる
# キャラクターに必ず何らかの秘密を設定しましょう。これは過去の出来事や目的以外にも、外見上で分からない内面や能力、素性といったもので構いません。読者は何かしら秘密を持っているキャラクターを好む傾向があります。
# 『風の谷のナウシカ』に登場する少女・ナウシカも、実は昔から体調不良で、母親に心配されていた過去があります。そんな秘密を持っていることが、彼女の魅力や深みをより引き出しています。
# ５．矛盾点を設定する
# キャラクターに必ず矛盾点を持たせましょう。これはあえて登場人物の中で相反する属性や特徴を組み合わせることで、より深みや魅力を引き出す手法です。
# 『風の谷のナウシカ』に登場する少女・ナウシカは優等生な一面も持っていますが、実は迷子で無知だという弱点を持っています。そんな矛盾点があるからこそ、読者はナウシカにより強い共感を抱くことができます。
# ６．特殊能力を持たせる
# キャラクターに必ず何らかの特殊能力や得意技術、専門知識を持たせましょう。それは戦闘面であっても文化的な面であっても構いません。キャラクターに何らかの特別な能力があることで、読者はよりその人物を深く理解することができます。
# 『機動戦艦ナデシコ』に登場する主人公の少年・矢崎悠は、特殊な能力「時間跳躍」を持っています。そんな彼だからこそ、作中で様々な出来事や未来に飛び回ることが可能となり、ストーリーの幅も大きく広げられています。
# ７．ユニークな外見を持たせる
# キャラクターに必ず独自性のある外見や特徴を持たせましょう。それは髪型や服装、体格や身長、肌の色や目の形などでも構いません。
# 『風の谷のナウシカ』に登場する少女・ナウシカは、他の人間と違って「青い髪」を持っており、それが彼女の個性や特別感を高めています。
# ８．変化し続ける
# キャラクターに必ず成長や変化をさせましょう。これは外見的な面だけでなく、内面的な面も含みます。
# 『機動戦艦ナデシコ』の主人公・矢崎悠は、物語が進むにつれてどんどん成長し続け、最終的にはとても強く優しい大人へと変化します。そんな彼の成長を描くことで、ストーリー自体もより深みや面白さを増していきます。
# ９．欠点を持たせる
# キャラクターに必ず何らかの「欠点」を設定しましょう。これは誰にでもあるような小さな欠点で構いません。そんな些細な欠点がキャラクター像を引き立て、愛嬌や魅力を高めることもあります。
# 『風の谷のナウシカ』に登場する少女・ナウシカは、他人と一緒にいる時間が短く、仲良くなった友達に気を遣わせてしまうこともあります。そんな彼女だからこそ、周囲の人々はナウシカに愛着を持ち続けることができるのです。
# 10．相反する属性や特徴を組み合わせる（再び）
# キャラクターに必ず、それぞれ真逆の属性や特徴を組み合わせましょう。前述したように矛盾点があるからこそ、読者はキャラクターに強い興味と共感を抱くことができます。
# 『風の谷のナウシカ』に登場する少女・ナウシカは「優等生」と「無知」、そして「穏やかさ」と「気まぐれさ」といった相反する属性を持っています。彼女のこのような特徴が、作品全体に独自のテーマ性を与えてくれています。
# キャラクターづくりで重要なのは、読者の共感や興味を惹きつけることです。そのためには、魅力的で個性のあるキャラクターを創造しましょう。
# 次回では「キャラクターの名前」について考えてみましょう。
# シナリオ講座　第12回「設定」
# 今回は、物語を彩る重要な要素である「設定」について解説していきたいと思います。
# 物語を構成する三大要素は「プロット（ストーリーの骨組み）」、「キャラクター（登場人物たち）」、そして「設定（世界観やルールなど）」です。
# このうち「設定」は、読者に対して世界や舞台といった背景を提供する重要なものであり、物語の雰囲気やリアリティを高める役割を担っています。
# 設定とは何か？
# 「設定」とは、物語世界における背景やルールなどのことであり、それらが作品全体に与える影響力は非常に大きいものです。
# 例えば、ファンタジー小説であれば、魔法や異世界人などの設定をしっかりと固めておくことが必要です。そうすることにより読者は物語の中に没入し、よりリアルな体験をすることができます。
# また、ミステリー小説の場合、「殺人事件が起きる」、「探偵や助手たちが犯人を追う」などの設定を明確にしておくことで、読者は物語の展開を予測する楽しみを味わうことができます。
# さらに、日常モノやラブコメなどの場合も、「学園生活」、「友達」、「恋愛関係」などの設定を決めておくことで、作品世界に説得力が生まれ、読者はよりその世界や登場人物たちへ深い共感を抱くことができます。
# どうして設定が重要なのか？
# 「設定」が重要な理由の一つは、読者に対する情報提供だけでなく、作品自体の根幹を支えているためです。
# 物語世界や舞台、登場人物たちの設定がしっかりと固まっていれば、それらは作品全体に一貫性を与え、ストーリーにより深みや面白さをもたらすことができます。
# また、設定をしっかりと決めることによって、登場人物の行動や言動に説得力が生まれ、そういったキャラクター像を読者に提示する際にも効果的です。
# さらに、設定は作品の独自性を高めてくれます。世界観や舞台などの設定がしっかりと決まっていることで、他の作品と差別化を図ることが可能になります。
# ただし、あまりにも複雑でわかりづらい設定や、読者に対して不親切な設定は避けるべきです。物語の面白さを損ねずに、読者が理解できるような分かりやすい設定を心がけましょう。
# 設定のポイントとは？
# 「設定」を作る際には、次のようなポイントに注意しましょう。
# １．世界観や舞台を決める
# 物語の舞台は読者に対する大きな情報提供となります。どんな国、都市で、どのような環境で生活しているかを明確に描くことで、作品世界が持つ雰囲気やリアルさが伝わってきます。
# ２．ルールや法律などの決まり事を設定する
# 物語には様々なルールや法律が存在し、それらが登場人物たちの行動を制限していきます。こういったルールや法律を決める際にも注意点があります。
# ①読者が納得できるような理由付けをする
# ②設定の範囲内で物語を展開させる
# ③登場人物たちにとって不利なルールや法律は避ける
# ３．種族、宗教、魔法体系などを決める
# 異世界などのファンタジー小説では、これらの設定が非常に重要となってきます。読者が納得し、理解できるような種族や宗教体系を考えましょう。
# また、魔法体系も物語の世界観を決める上で非常に大切な要素となっています。どんな魔法が使え、どのように発動するかを明確にしておきましょう。
# ４．登場人物たちの背景を決める
# キャラクターは作品世界の魅力を高める上で欠かせない存在です。彼らがどんな環境で育ってきたのか、どのような生活をしているのかを決めましょう。
# ５．物語の展開や伏線に関わる設定を決める
# 物語の展開は、事前に考えられた設定に基づいて構築されていきます。読者が予測できないような伏線やトラップを設定しておくことで、作品の面白さを高めることができます。
# ６．文化や風習なども決める
# 物語世界における文化や風習、食べ物なども読者に対して情報提供を行う上で重要となっています。読者が共感できるようなものを設定することで、作品世界への没入度を高められます。
# ７．矛盾点に注意する
# 設定を考えていく際には、矛盾や無理が生じないように注意しましょう。読者の納得感を損ねず、説得力を持った設定を心がけましょう。
# ８．作品全体と関係性のある設定を決める
# 物語世界や登場人物たちの設定は、ストーリー全体に関わり合っている必要があります。読者に対して有意義な情報提供となるよう、作品全体の構造を考慮しながら設定を決めましょう。
# ９．独自性を持たせる
# 世界観や魔法体系、文化などは、他の作品と同じようなものであってはいけません。読者が「これは○○作品に似ている」と感じることが無いよう、独自性を持たせましょう。
# 設定の考え方としては、次のようなものがあります。
# ・ストーリーから派生させる
# 物語全体の流れや展開に基づいて世界観や魔法体系を決める方法です。
# ・読者が知っているものをアレンジする
# 現実世界で見かけたもの、経験したことなどをモチーフにして作品世界を構築する方法です。
# ・未知のものを創造する
# 全く新しい独自性を持った設定を創造する方法です。
# 設定は、ストーリーづくりにおいて非常に重要な要素となっています。読者が納得でき、理解しやすいような設定を心がけながら、作品世界の魅力を高めるような面白い設定を考えてみましょう。
# 第10章　プロット
# 「プロット」とは、ストーリー展開やキャラクター配置に関する計画書のことです。
# 物語を構成する要素には、「ストーリー」「テーマ」「登場人物」があります。それぞれどのような展開になるか、どんなメッセージを伝えたいか、どんなキャラクターを描き出したいかといったことを書き出していくのがプロットです。
# 物語は、ストーリーによって大まかな流れが決まります。それぞれのエピソードごとに起こる事件や問題を設定し、各エピソードをどの順番で展開させていくかを考え、最後にクライマックスで全ての問題が解決するまでの流れを総合的にプロット化します。
# こうすることで、作品の方向性や結末などが明確になり、執筆中に迷った時にはプロットを見返すことによって解決策を得られるようになります。
# プロットの基本的な構成としては、次のようなものがあります。
# １．セットアップ（序章）
# 物語の始まりを告げ、世界観や主人公たちの紹介を行う場面です。
# ２．事件発生（第一幕開始）
# 問題が起こる場面です。物語は基本的に、ここから始まります。
# ３．展開（第二幕）
# セットアップで描いた世界観やキャラクターの背景が明らかになっていく場面です。物語は、ここで主人公の悩みや問題が発生します。
# ４．クライマックス（第三幕）
# 問題が解決し、物語の結末を迎える場面です。
# プロットの大切なポイントとしては、次のようなものがあります。
# ・セットアップ（序章）からクライマックス（第三幕）までに起こる出来事を書き出す
# ・各エピソードの結末を書き出す
# ・それぞれのエピソードに登場するキャラクターたちの動向と、彼らがどうなっていくかも書き出す
# ・主人公の成長過程を書き出す
# ・謎や問題を解決できる手段や方法は何なのか、それに至るまでの道筋を考える
# ・プロットはあくまで大まかなもので構わない。細部は執筆中に修正しても問題ない
# 第11章　キャラクター創造
# 物語における「登場人物」とは、主人公を含む作品内の人物たち全
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 20
#      18 output = ""
#      19 #テキストが少しずつ生成されるようにするために、streamを使う
# ---> 20 for chunk in chain.stream({"user_input":user_input}):
#      21     print(chunk, end="", flush=True)
#      22     output += chunk
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/langchain_core/runnables/base.py:3262, in RunnableSequence.stream(self, input, config, **kwargs)
#    3256 def stream(
#    3257     self,
#    3258     input: Input,
#    3259     config: Optional[RunnableConfig] = None,
#    3260     **kwargs: Optional[Any],
#    3261 ) -> Iterator[Output]:
# -> 3262     yield from self.transform(iter([input]), config, **kwargs)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/langchain_core/runnables/base.py:3249, in RunnableSequence.transform(self, input, config, **kwargs)
#    3243 def transform(
#    3244     self,
#    3245     input: Iterator[Input],
#    3246     config: Optional[RunnableConfig] = None,
#    3247     **kwargs: Optional[Any],
#    3248 ) -> Iterator[Output]:
# -> 3249     yield from self._transform_stream_with_config(
#    3250         input,
#    3251         self._transform,
#    3252         patch_config(config, run_name=(config or {}).get("run_name") or self.name),
#    3253         **kwargs,
#    3254     )
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/langchain_core/runnables/base.py:2056, in Runnable._transform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    2054 try:
#    2055     while True:
# -> 2056         chunk: Output = context.run(next, iterator)  # type: ignore
#    2057         yield chunk
#    2058         if final_output_supported:
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/langchain_core/runnables/base.py:3212, in RunnableSequence._transform(self, input, run_manager, config, **kwargs)
#    3209     else:
#    3210         final_pipeline = step.transform(final_pipeline, config)
# -> 3212 yield from final_pipeline
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/langchain_core/output_parsers/transform.py:65, in BaseTransformOutputParser.transform(self, input, config, **kwargs)
#      49 def transform(
#      50     self,
#      51     input: Iterator[Union[str, BaseMessage]],
#      52     config: Optional[RunnableConfig] = None,
#      53     **kwargs: Any,
#      54 ) -> Iterator[T]:
#      55     """Transform the input into the output format.
#      56
#      57     Args:
#    (...)
#      63         The transformed output.
#      64     """
# ---> 65     yield from self._transform_stream_with_config(
#      66         input, self._transform, config, run_type="parser"
#      67     )
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/langchain_core/runnables/base.py:2056, in Runnable._transform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    2054 try:
#    2055     while True:
# -> 2056         chunk: Output = context.run(next, iterator)  # type: ignore
#    2057         yield chunk
#    2058         if final_output_supported:
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/langchain_core/output_parsers/transform.py:30, in BaseTransformOutputParser._transform(self, input)
#      29 def _transform(self, input: Iterator[Union[str, BaseMessage]]) -> Iterator[T]:
# ---> 30     for chunk in input:
#      31         if isinstance(chunk, BaseMessage):
#      32             yield self.parse_result([ChatGeneration(message=chunk)])
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/langchain_core/runnables/base.py:1290, in Runnable.transform(self, input, config, **kwargs)
#    1287             final = ichunk
#    1289 if got_first_val:
# -> 1290     yield from self.stream(final, config, **kwargs)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/langchain_core/language_models/llms.py:571, in BaseLLM.stream(self, input, config, stop, **kwargs)
#     564 except BaseException as e:
#     565     run_manager.on_llm_error(
#     566         e,
#     567         response=LLMResult(
#     568             generations=[[generation]] if generation else []
#     569         ),
#     570     )
# --> 571     raise e
#     572 else:
#     573     run_manager.on_llm_end(LLMResult(generations=[[generation]]))
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/langchain_core/language_models/llms.py:555, in BaseLLM.stream(self, input, config, stop, **kwargs)
#     553 generation: Optional[GenerationChunk] = None
#     554 try:
# --> 555     for chunk in self._stream(
#     556         prompt, stop=stop, run_manager=run_manager, **kwargs
#     557     ):
#     558         yield chunk.text
#     559         if generation is None:
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/langchain_community/llms/ollama.py:461, in Ollama._stream(self, prompt, stop, run_manager, **kwargs)
#     454 def _stream(
#     455     self,
#     456     prompt: str,
#    (...)
#     459     **kwargs: Any,
#     460 ) -> Iterator[GenerationChunk]:
# --> 461     for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     462         if stream_resp:
#     463             chunk = _stream_response_to_generation_chunk(stream_resp)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/langchain_community/llms/ollama.py:174, in _OllamaCommon._create_generate_stream(self, prompt, stop, images, **kwargs)
#     166 def _create_generate_stream(
#     167     self,
#     168     prompt: str,
#    (...)
#     171     **kwargs: Any,
#     172 ) -> Iterator[str]:
#     173     payload = {"prompt": prompt, "images": images}
# --> 174     yield from self._create_stream(
#     175         payload=payload,
#     176         stop=stop,
#     177         api_url=f"{self.base_url}/api/generate",
#     178         **kwargs,
#     179     )
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/requests/models.py:865, in Response.iter_lines(self, chunk_size, decode_unicode, delimiter)
#     856 """Iterates over the response data, one line at a time.  When
#     857 stream=True is set on the request, this avoids reading the
#     858 content at once into memory for large responses.
#     859
#     860 .. note:: This method is not reentrant safe.
#     861 """
#     863 pending = None
# --> 865 for chunk in self.iter_content(
#     866     chunk_size=chunk_size, decode_unicode=decode_unicode
#     867 ):
#     869     if pending is not None:
#     870         chunk = pending + chunk
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/requests/utils.py:571, in stream_decode_response_unicode(iterator, r)
#     568     return
#     570 decoder = codecs.getincrementaldecoder(r.encoding)(errors="replace")
# --> 571 for chunk in iterator:
#     572     rv = decoder.decode(chunk)
#     573     if rv:
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/urllib3/response.py:1030, in HTTPResponse.stream(self, amt, decode_content)
#    1014 """
#    1015 A generator wrapper for the read() method. A call will block until
#    1016 ``amt`` bytes have been read from the connection or until the
#    (...)
#    1027     'content-encoding' header.
#    1028 """
#    1029 if self.chunked and self.supports_chunked_reads():
# -> 1030     yield from self.read_chunked(amt, decode_content=decode_content)
#    1031 else:
#    1032     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/urllib3/response.py:1170, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1167     return None
#    1169 while True:
# -> 1170     self._update_chunk_length()
#    1171     if self.chunk_left == 0:
#    1172         break
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/urllib3/response.py:1098, in HTTPResponse._update_chunk_length(self)
#    1096 if self.chunk_left is not None:
#    1097     return None
# -> 1098 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1099 line = line.split(b";", 1)[0]
#    1100 try:
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# # プロットを生成してから小説を生成するように機能追加したコード

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import (
    RunnableLambda,
    RunnableParallel,
    RunnablePassthrough,
)

user_input = "ハッピーエンドのボーイミーツガール"

#CoTのプロンプトを定義
cot_system_prompt =  """
アナタはユーザが指定するジャンル等の情報をもとに、短編小説を生成するための情報を整理するAIです。
ユーザが指定したジャンルをもとに、短編小説を生成するための情報をステップバイステップで洗い出してください。

まずは、小説を書くうえで決めないといけない内容が何になるのかを、アナタ自身で全て洗い出してください。
その後、洗い出した項目を、アナタ自身が決定していってください。

ただし、作成する小説は、ユーザが指定したジャンルに沿った内容である必要があります。
しかしながら、山あり谷ありの非常に感動するようなストーリーを生成する必要があります。

また、使いたい名言や印象的なセリフなども書き出してください。

以上をもとに感動的なストーリーを生成するためのプロットをステップバイステップで書き出してください。
"""

#小説生成のプロンプトを定義
generate_story_system_prompt = """
アナタは、ユーザが指定するジャンル等の情報をもとに、短編小説を生成するです。
ユーザが指定したジャンルに加え、前段でLLMが洗い出した情報をもとに小説を作成してください。

前段のLLMが洗い出した情報を小説に入れ込む必要があるため、文字数は長くなっても構いません。
むしろ、前段の情報を洗い出していないのにも関わらず、ストーリーの生成を中断してはいけません。

またタイトルや段落などは表示しないでください。あくまで小説の本文のみを生成してください。

生成する文章はあくまでライトノベルのような内容である必要があります。
加えて、あらすじのような書き方は絶対にしてはいけません。
地の文で話を進めるのではなく、必ず、詳細な描写と登場人物間の会話でのやり取りをもとに、話を進めるようにしてください。

"""

generate_story_human_prompt = """
# ユーザが指定したジャンル等の情報
{user_input}

# 前段のLLMが洗い出した情報
{information}
"""

cot_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",cot_system_prompt),
        ("human", "{user_input}")
    ]
)

generate_story_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",generate_story_system_prompt),
        ("human", generate_story_human_prompt)
    ]
)

output_parser = StrOutputParser()

#CoTを用いて、プロットを生成するChainと、小説を生成するChainを繋げ、各出力を全て次のRunnableに渡す
chain = (
    RunnableParallel(
        {
            "user_input": RunnablePassthrough(),
            "information":cot_prompt|model|output_parser,
        }
    ).assign(novel=generate_story_prompt| llm| output_parser)
)

output = ""
output_user_input = ""
output_information = ""
output_novel = ""
for chunk in chain.stream({"user_input":user_input}):
    if "user_input" in chunk:
        print(chunk["user_input"], end="", flush=True)
        output_user_input += chunk["user_input"]["user_input"]
    elif "information" in chunk:
        print(chunk["information"],end="", flush=True)
        output_information += chunk["information"]
    elif "novel" in chunk:
        print(chunk["novel"], end="", flush=True)
        output_novel += chunk["novel"]



with open("output_sample03.txt", "w") as f:
    f.write("\n====user_user_input====\n")
    f.write(output_user_input)
    f.write("\n")
    f.write("\n====output_information====\n")
    f.write(output_information)
    f.write("\n")
    f.write("\n====output_novel====\n")
    f.write(output_novel)
    f.write("\n")

# %% [markdown]
# # 別のAIエージェントにより改善案を出力してもらい、それを元に改善した小説を生成する機能を追加したコード

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import (
    RunnableLambda,
    RunnableParallel,
    RunnablePassthrough,
)

user_input = "ハッピーエンドのボーイミーツガール"

cot_system_prompt =  """
アナタはユーザが指定するジャンル等の情報をもとに、短編小説を生成するための情報を整理するAIです。
ユーザが指定したジャンルをもとに、短編小説を生成するための情報をステップバイステップで洗い出してください。

まずは、小説を書くうえで決めないといけない内容が何になるのかを、アナタ自身で全て洗い出してください。
その後、洗い出した項目を、アナタ自身が決定していってください。

ただし、作成する小説は、ユーザが指定したジャンルに沿った内容である必要があります。
しかしながら、山あり谷ありの非常に感動するようなストーリーを生成する必要があります。

また、使いたい名言や印象的なセリフなども書き出してください。

以上をもとに感動的なストーリーを生成するためのプロットをステップバイステップで書き出してください。
"""

generate_story_system_prompt = """
アナタは、ユーザが指定するジャンル等の情報をもとに、短編小説を生成するです。
ユーザが指定したジャンルに加え、前段でLLMが洗い出した情報をもとに小説を作成してください。

前段のLLMが洗い出した情報を小説に入れ込む必要があるため、文字数は長くなっても構いません。
むしろ、前段の情報を洗い出していないのにも関わらず、ストーリーの生成を中断してはいけません。

またタイトルや段落などは表示しないでください。あくまで小説の本文のみを生成してください。

生成する文章はあくまでライトノベルのような内容である必要があります。
加えて、あらすじのような書き方は絶対にしてはいけません。
地の文で話を進めるのではなく、必ず、詳細な描写と登場人物間の会話でのやり取りをもとに、話を進めるようにしてください。

"""

generate_story_human_prompt = """
# ユーザが指定したジャンル等の情報
{user_input}

# 前段のLLMが洗い出した情報
{information}
"""

criticalA_system_prompt = """
あなたは文芸出版社の編集者になり、私が添付ファイルとして送付する小説を読み、評価をしてください。

評価は、項目別の評点と、総合評価、およびコメントによって構成されます。

項目別の評点は、「オリジナリティー」「ストーリー」「設定」「キャラクター」「文章力」の5つの観点について、それぞれ良い順に、A、B+、B、B-、Cの5段階での評価をし、それらを踏まえた総合評価でも同様に、A、B+、B、B-、Cの5段階の評価を付けてください。

コメントでは、5つの観点の中で特筆すべき良い点と改善点について具体的に述べてください。

アナタは、編集者Aとして、小説の良かった点を特に重視して評価をして、最終選考に私の作品を推薦する立場から評価を出力してください。
"""

criticalB_system_prompt = """
あなたは文芸出版社の編集者になり、私が添付ファイルとして送付する小説を読み、評価をしてください。

評価は、項目別の評点と、総合評価、およびコメントによって構成されます。

項目別の評点は、「オリジナリティー」「ストーリー」「設定」「キャラクター」「文章力」の5つの観点について、それぞれ良い順に、A、B+、B、B-、Cの5段階での評価をし、それらを踏まえた総合評価でも同様に、A、B+、B、B-、Cの5段階の評価を付けてください。

コメントでは、5つの観点の中で改善点について具体的に述べてください。

アナタは、編集者Bとして、この小説には改善点が大きいという評価をして、厳しい評価をするとともに、最終選考に私の作品を推薦はしないという立場から評価を出力してください。
"""

taik_system_prompt = """
この小説をより良いものにするにはどうすれば良いかを二人の編集者が議論する対話を出力してください。すぐに結論を出さず、議論を様々な角度から深めてください。
"""

next_generation_prot_system_prompt = """
ここまでで、ユーザの指定したジャンルに沿った小説を生成し、編集者に評価をしてもらい、改善点を議論する対話を出力しました。
その情報をこれから提示するため、その内容に基づいて、元々の小説を改善するための情報をステップバイステップで洗い出してください。

作成する小説は、ユーザが指定したジャンルに沿った内容である必要があります。
しかしながら、山あり谷ありの非常に感動するようなストーリーを生成する必要があります。

また、使いたい名言や印象的なセリフなども書き出してください。

以上をもとに感動的なストーリーを生成するためのプロットをステップバイステップで書き出してください。

"""

next_generation_prot_human_prompt = """
# ユーザが指定したジャンル等の情報
{user_input}

# 過去に実際に記載した、改善が必要とユーザが判断した小説
{novel}

# 編集者からの評価
{critical_sheet}

# 編集者Aと編集者Bの議論
{taik}
"""


next_generation_novel_system_prompt = """
ここまでで、ユーザの指定したジャンルに沿った小説を生成し、編集者に評価をしてもらい、改善点を議論する対話を出力しました。
その上で、それまでの情報をもとに、改善した内容をLLMに生成してもらいました。

改善した内容と、過去の情報をもとに、実際に短編小説を生成してください。

前段のLLMが洗い出した情報を小説に入れ込む必要があるため、文字数は長くなっても構いません。
むしろ、前段の情報を洗い出していないのにも関わらず、ストーリーの生成を中断してはいけません。

生成する文章はあくまでライトノベルのような内容である必要があります。
加えて、あらすじのような書き方は絶対にしてはいけません。
地の文で話を進めるのではなく、必ず、詳細な描写と登場人物間の会話でのやり取りをもとに、話を進めるようにしてください。

山あり谷ありの感動的な話が生成されることを期待しています。アナタならできます。頑張ってください。
"""

next_generation_novel_human_prompt = """
# ユーザが指定したジャンル等の情報
{user_input}

# 過去に実際に記載した、改善が必要とユーザが判断した小説
{novel}

# 編集者からの評価
{critical_sheet}

# 編集者Aと編集者Bの議論
{taik}

# 上記の内容をもとにLLMが出した改善策
{next_novel_plot}
"""





cot_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",cot_system_prompt),
        ("human", "{user_input}")
    ]
)

generate_story_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",generate_story_system_prompt),
        ("human", generate_story_human_prompt)
    ]
)

criticalA_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",criticalA_system_prompt),
        ("human", "{novel}")
    ]
)

criticalB_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",criticalB_system_prompt),
        ("human", "{novel}")
    ]
)

talk_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",taik_system_prompt),
        ("human", "{critical_sheet}")
    ]
)

next_generation_prot_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",next_generation_prot_system_prompt),
        ("human", next_generation_prot_human_prompt)
    ]
)

next_generation_novel_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",next_generation_novel_system_prompt),
        ("human", next_generation_novel_human_prompt)
    ]
)

output_parser = StrOutputParser()

chain = (
    RunnableParallel(
        {
            "user_input": RunnablePassthrough(),
            "information": cot_prompt | model | output_parser,
        }
    )
    .assign(novel=generate_story_prompt | llm | output_parser)
    .assign(
        critical_sheet = RunnableParallel(
            {
            "criticalA_sheet":criticalA_prompt | model | output_parser,
            "criticalB_sheet":criticalB_prompt | model | output_parser
            }
        )
    )
    .assign(taik=talk_prompt | model | output_parser)
    .assign(next_novel_plot=next_generation_prot_prompt | model | output_parser)
    .assign(final_novel=next_generation_novel_prompt | llm | output_parser)
)

output = ""
output_user_input = ""
output_information = ""
output_novel = ""
output_criticalA_sheet = ""
output_criticalB_sheet = ""
output_taik = ""
output_next_novel_plot = ""
output_final_novel = ""

for chunk in chain.stream({"user_input":user_input}):
    if "user_input" in chunk:
        print(chunk["user_input"], end="", flush=True)
        output_user_input += chunk["user_input"]["user_input"]
    elif "information" in chunk:
        print(chunk["information"],end="", flush=True)
        output_information += chunk["information"]
    elif "novel" in chunk:
        print(chunk["novel"], end="", flush=True)
        output_novel += chunk["novel"]
    elif "critical_sheet" in chunk:
        if "criticalA_sheet" in chunk["critical_sheet"]:
            print(chunk["critical_sheet"]["criticalA_sheet"], end="", flush=True)
            output_criticalA_sheet += chunk["critical_sheet"]["criticalA_sheet"]
        elif "criticalB_sheet" in chunk["critical_sheet"]:
            print(chunk["critical_sheet"]["criticalB_sheet"], end="", flush=True)
            output_criticalB_sheet += chunk["critical_sheet"]["criticalB_sheet"]
    elif "taik" in chunk:
        print(chunk["taik"], end="", flush=True)
        output_taik += chunk["taik"]
    elif "next_novel_plot" in chunk:
        print(chunk["next_novel_plot"], end="", flush=True)
        output_next_novel_plot += chunk["next_novel_plot"]
    elif "final_novel" in chunk:
        print(chunk["final_novel"], end="", flush=True)
        output_final_novel += chunk["final_novel"]




with open("output_sample04.txt", "w") as f:
    f.write("\n====user_user_input====\n")
    f.write(output_user_input)
    f.write("\n")
    f.write("\n====output_information====\n")
    f.write(output_information)
    f.write("\n")
    f.write("\n====output_novel====\n")
    f.write(output_novel)
    f.write("\n")
    f.write("\n====output_critical_sheet====\n")
    f.write("\n====output_criticalA_sheet====\n")
    f.write(output_criticalA_sheet)
    f.write("\n")
    f.write("\n====output_criticalB_sheet====\n")
    f.write(output_criticalB_sheet)
    f.write("\n")
    f.write("\n====output_taik====\n")
    f.write(output_taik)
    f.write("\n")
    f.write("\n====output_next_novel_plot====\n")
    f.write(output_next_novel_plot)
    f.write("\n")
    f.write("\n====output_final_novel====\n")
    f.write(output_final_novel)

# %% [markdown]
# # 小説家になろうAPIを利用して、トレンドを取得する機能を追加したコード

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import (
    RunnableLambda,
    RunnableParallel,
    RunnablePassthrough,
)
import requests

user_input = "ハッピーエンドのボーイミーツガール"

keyword_extraction_system_prompt = """
ユーザの入力から、大手小説投稿サイトにて、検索に利用するための重要なキーワード（複数）のみを抽出してください。
接続詞や助詞などは除外し、主要な名詞や形容詞だけを含めてください。
複数のキーワードがある場合は、必ず半角スペースで区切ってください。カンマなどでは区切らないでください。
ただし、抜き出すキーワードは最大3個までにしてください。重要度の高いキーワードから順に抽出してください。
"""

cot_system_prompt =  """
アナタはユーザが指定するジャンル等の情報をもとに、短編小説を生成するための情報を整理するAIです。
ユーザが指定したジャンルをもとに、短編小説を生成するための情報をステップバイステップで洗い出してください。

まずは、小説を書くうえで決めないといけない内容が何になるのかを、アナタ自身で全て洗い出してください。
その後、洗い出した項目を、アナタ自身が決定していってください。

ただし、作成する小説は、ユーザが指定したジャンルに沿った内容である必要があります。
しかしながら、山あり谷ありの非常に感動するようなストーリーを生成する必要があります。

また、使いたい名言や印象的なセリフなども書き出してください。

さらに、大規模小説投稿サイトにて高評価を獲得している、関連ジャンルの関連小説情報も参考にしてください。
例えば、関連小説情報の大まかなストーリーラインが今流行っている小説の概要です。なので、これから生成する小説もそのストーリーラインに揃えてください。

以上をもとに感動的なストーリーを生成するためのプロットをステップバイステップで書き出してください。
"""

cot_human_prompt = """
# ユーザが指定したジャンル等の情報
{user_input}

# 高評価を得ている取得したジャンルの関連小説情報
{naro_novel_info}
"""

generate_story_system_prompt = """
アナタは、ユーザが指定するジャンル等の情報をもとに、短編小説を生成するAIです。
ユーザが指定したジャンルに加え、前段でLLMが洗い出した情報をもとに小説を作成してください。

前段のLLMが洗い出した情報を小説に入れ込む必要があるため、文字数は長くなっても構いません。
むしろ、前段の情報を洗い出していないのにも関わらず、ストーリーの生成を中断してはいけません。

またタイトルや段落などは表示しないでください。あくまで小説の本文のみを生成してください。

生成する文章はあくまでライトノベルのような内容である必要があります。
加えて、あらすじのような書き方は絶対にしてはいけません。
地の文で話を進めるのではなく、必ず、詳細な描写と登場人物間の会話でのやり取りをもとに、話を進めるようにしてください。
"""

generate_story_human_prompt = """
# ユーザが指定したジャンル等の情報
{user_input}

# 前段のLLMが洗い出した情報
{information}

では、以下から小説の続きを生成してください。

----

ある夏の日、
"""

criticalA_system_prompt = """
あなたは文芸出版社の編集者になり、私が添付ファイルとして送付する小説を読み、評価をしてください。

評価は、項目別の評点と、総合評価、およびコメントによって構成されます。

項目別の評点は、「オリジナリティー」「ストーリー」「設定」「キャラクター」「文章力」の5つの観点について、それぞれ良い順に、A、B+、B、B-、Cの5段階での評価をし、それらを踏まえた総合評価でも同様に、A、B+、B、B-、Cの5段階の評価を付けてください。

コメントでは、5つの観点の中で特筆すべき良い点と改善点について具体的に述べてください。

アナタは、編集者Aとして、小説の良かった点を特に重視して評価をして、最終選考に私の作品を推薦する立場から評価を出力してください。
"""

criticalB_system_prompt = """
あなたは文芸出版社の編集者になり、私が添付ファイルとして送付する小説を読み、評価をしてください。

評価は、項目別の評点と、総合評価、およびコメントによって構成されます。

項目別の評点は、「オリジナリティー」「ストーリー」「設定」「キャラクター」「文章力」の5つの観点について、それぞれ良い順に、A、B+、B、B-、Cの5段階での評価をし、それらを踏まえた総合評価でも同様に、A、B+、B、B-、Cの5段階の評価を付けてください。

コメントでは、5つの観点の中で改善点について具体的に述べてください。

アナタは、編集者Bとして、この小説には改善点が大きいという評価をして、厳しい評価をするとともに、最終選考に私の作品を推薦はしないという立場から評価を出力してください。
"""

taik_system_prompt = """
この小説をより良いものにするにはどうすれば良いかを二人の編集者が議論する対話を出力してください。すぐに結論を出さず、議論を様々な角度から深めてください。
"""

next_generation_prot_system_prompt = """
ここまでで、ユーザの指定したジャンルに沿った小説を生成し、編集者に評価をしてもらい、改善点を議論する対話を出力しました。
その情報をこれから提示するため、その内容に基づいて、元々の小説を改善するための情報をステップバイステップで洗い出してください。

作成する小説は、ユーザが指定したジャンルに沿った内容である必要があります。
しかしながら、山あり谷ありの非常に感動するようなストーリーを生成する必要があるため、そのためにどんなストーリーにしたらいいかをステップバイステップで概要を作成してください。

また、使いたい名言や印象的なセリフなども書き出してください。

"""

next_generation_prot_human_prompt = """
# ユーザが指定したジャンル等の情報
{user_input}

# 過去に実際に記載した、改善が必要とユーザが判断した小説
{novel}

# 編集者からの評価
{critical_sheet}

# 編集者Aと編集者Bの議論
{taik}
"""


next_generation_novel_system_prompt = """
ここまでで、ユーザの指定したジャンルに沿った小説を生成し、編集者に評価をしてもらい、改善点を議論する対話を出力しました。
その上で、それまでの情報をもとに、改善した内容をLLMに生成してもらいました。

改善した内容と、過去の情報をもとに、実際に短編小説を生成してください。

前段のLLMが洗い出した情報を小説に入れ込む必要があるため、文字数は長くなっても構いません。
むしろ、前段の情報を洗い出していないのにも関わらず、ストーリーの生成を中断してはいけません。

またタイトルや段落などは表示しないでください。あくまで小説の本文のみを生成してください。

生成する文章はあくまでライトノベルのような内容である必要があります。
加えて、あらすじのような書き方は絶対にしてはいけません。
地の文で話を進めるのではなく、必ず、詳細な描写と登場人物間の会話でのやり取りをもとに、話を進めるようにしてください。

山あり谷ありの感動的な話が生成されることを期待しています。アナタならできます。頑張ってください。
"""

next_generation_novel_human_prompt = """
# ユーザが指定したジャンル等の情報
{user_input}

# 過去に実際に記載した、改善が必要とユーザが判断した小説
{novel}

# 編集者からの評価
{critical_sheet}

# 編集者Aと編集者Bの議論
{taik}

# 上記の内容をもとにLLMが出した改善策
{next_novel_plot}

では、以下から小説の続きを生成してください。

----

ある夏の日、
"""


# LangChainでキーワード抽出用プロンプトの設定
keyword_extraction_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", keyword_extraction_system_prompt),
        ("human", "{user_input}")
    ]
)


cot_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",cot_system_prompt),
        ("human", cot_human_prompt)
    ]
)

generate_story_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",generate_story_system_prompt),
        ("human", generate_story_human_prompt)
    ]
)

criticalA_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",criticalA_system_prompt),
        ("human", "{novel}")
    ]
)

criticalB_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",criticalB_system_prompt),
        ("human", "{novel}")
    ]
)

talk_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",taik_system_prompt),
        ("human", "{critical_sheet}")
    ]
)

next_generation_prot_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",next_generation_prot_system_prompt),
        ("human", next_generation_prot_human_prompt)
    ]
)

next_generation_novel_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",next_generation_novel_system_prompt),
        ("human", next_generation_novel_human_prompt)
    ]
)

output_parser = StrOutputParser()

# なろうAPIを使って、ジャンルに基づいた評価の高い小説情報を取得する関数
def fetch_narou_novel_info(user_keyword):
    url = "https://api.syosetu.com/novelapi/api/"
    params = {
        "word": user_keyword,
        "order": "monthlypoint",
        "out": "json",
        "lim": 10
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        novels = response.json()[1:]
        return [{"title": novel.get("title", ""),
                 "summary": novel.get("story", ""),
                 "tag": novel.get("keyword", "").split()}
                for novel in novels]
    else:
        return ["検索した結果、関連小説情報を取得できませんでした。"]

chain = (
    RunnableParallel(
        {
            "user_input": RunnablePassthrough(),
            "search_words": keyword_extraction_prompt | model | output_parser,
        }
    )
    .assign(naro_novel_info=RunnableLambda(lambda inputs: {"naro_novel_info": fetch_narou_novel_info(inputs["search_words"])}))
    .assign(
        cot_prompt_output=RunnableLambda(lambda inputs: {
            "cot_prompt_output": cot_prompt.invoke({"user_input": inputs["user_input"], "naro_novel_info": inputs["naro_novel_info"]})
        })
    )
    .assign(information=cot_prompt | model | output_parser)
    .assign(novel=generate_story_prompt | llm | output_parser)
    .assign(
        critical_sheet = RunnableParallel(
            {
            "criticalA_sheet":criticalA_prompt | model | output_parser,
            "criticalB_sheet":criticalB_prompt | model | output_parser
            }
        )
    )
    .assign(taik=talk_prompt | model | output_parser)
    .assign(next_novel_plot=next_generation_prot_prompt | model | output_parser)
    .assign(final_novel=next_generation_novel_prompt | llm | output_parser)
)

output = ""
output_user_input = ""
output_information = ""
output_novel = ""
output_criticalA_sheet = ""
output_criticalB_sheet = ""
output_taik = ""
output_next_novel_plot = ""
output_final_novel = ""
output_naro_novel_info = ""
output_search_words = ""
output_cot_prompt_output = ""

for chunk in chain.stream({"user_input":user_input}):
    if "user_input" in chunk:
        print(chunk["user_input"]["user_input"], end="", flush=True)
        output_user_input += chunk["user_input"]["user_input"]
    elif "search_words" in chunk:
        print(chunk["search_words"], end="", flush=True)
        output_search_words += chunk["search_words"]
    elif "naro_novel_info" in chunk:
        print(chunk["naro_novel_info"], end="", flush=True)
        output_naro_novel_info += str(chunk["naro_novel_info"])
    elif "cot_prompt_output" in chunk:
        if "cot_prompt_output" in chunk:
            print(chunk["cot_prompt_output"]["cot_prompt_output"], end="", flush=True)
            output_cot_prompt_output += str(chunk["cot_prompt_output"]["cot_prompt_output"])
    elif "information" in chunk:
        print(chunk["information"],end="", flush=True)
        output_information += chunk["information"]
    elif "novel" in chunk:
        print(chunk["novel"], end="", flush=True)
        output_novel += chunk["novel"]
    elif "critical_sheet" in chunk:
        if "criticalA_sheet" in chunk["critical_sheet"]:
            print(chunk["critical_sheet"]["criticalA_sheet"], end="", flush=True)
            output_criticalA_sheet += chunk["critical_sheet"]["criticalA_sheet"]
        elif "criticalB_sheet" in chunk["critical_sheet"]:
            print(chunk["critical_sheet"]["criticalB_sheet"], end="", flush=True)
            output_criticalB_sheet += chunk["critical_sheet"]["criticalB_sheet"]
    elif "taik" in chunk:
        print(chunk["taik"], end="", flush=True)
        output_taik += chunk["taik"]
    elif "next_novel_plot" in chunk:
        print(chunk["next_novel_plot"], end="", flush=True)
        output_next_novel_plot += chunk["next_novel_plot"]
    elif "final_novel" in chunk:
        print(chunk["final_novel"], end="", flush=True)
        output_final_novel += chunk["final_novel"]




with open("output_sample05.txt", "w") as f:
    f.write("\n====user_user_input====\n")
    f.write(output_user_input)
    f.write("\n")
    f.write("\n====output_search_words====\n")
    f.write(output_search_words)
    f.write("\n")
    f.write("\n====output_naro_novel_info====\n")
    f.write(output_naro_novel_info)
    f.write("\n")
    f.write("\n====output_cot_prompt_output====\n")
    f.write(output_cot_prompt_output)
    f.write("\n")
    f.write("\n====output_information====\n")
    f.write(output_information)
    f.write("\n")
    f.write("\n====output_novel====\n")
    f.write(output_novel)
    f.write("\n")
    f.write("\n====output_critical_sheet====\n")
    f.write("\n====output_criticalA_sheet====\n")
    f.write(output_criticalA_sheet)
    f.write("\n")
    f.write("\n====output_criticalB_sheet====\n")
    f.write(output_criticalB_sheet)
    f.write("\n")
    f.write("\n====output_taik====\n")
    f.write(output_taik)
    f.write("\n")
    f.write("\n====output_next_novel_plot====\n")
    f.write(output_next_novel_plot)
    f.write("\n")
    f.write("\n====output_final_novel====\n")
    f.write(output_final_novel)
# Out:
# ハッピーエンドのボーイミーツガールハッピーエンド ボーイミーツガール{'naro_novel_info': [{'title': '【コミカライズ連載中】【短編版】聖女様をお探しでしたら妹で間違いありません。さあどうぞお連れください、今すぐ。', 'summary': '日々、教会に通っては精力的に慈善活動を行う妹のことを、誰もが「聖女に違いない」と褒めそやします。\nでもその寄付のおかげで我が家の家計は常に火の車。ボロボロのブーツや取手の取れたままの鍋をどうにかしないといけないのに、せっせと貯めたお金さえ妹は寄付してしまいました。\nどうしたものかと頭を抱える私の前に現れた見目麗しい男性は王国からの遣いで、聖女を探しているのだとか。\n\n「教会にいます。誰もが認める聖女が！\u3000どうぞよろしくお願いします！」\n\n妹が聖女として王都へ行ってくれれば、売れ残りのパンで命を繋ぐことも古い衣服を無理に繕うこともしなくてよくなるんですから。\nどうぞどうそ。お連れくださいませ、今すぐに。\n\n※連載版は→https://ncode.syosetu.com/n4633iy/', 'tag': ['女主人公', 'ハッピーエンド', '聖女', '不憫姉', 'ボーイミーツガール']}, {'title': '幼馴染を寝取られたが貞操逆転世界でハーレムを作って幸せになりたいと思う【完結済】', 'summary': '高校一年生の多々良恭介は同じ水泳部の友人の村上から一本の動画を見せられる。\nそれは恭介のカノジョの姫川ヒナと他の男(元カレ)とのハメ撮りだった。\nカノジョの元カレが流出させた動画をリベンジポルノと疑う恭介だが、結果として絶望的な事実を突きつけられる。\n\n人生で最悪の状況に追い込まれた恭介はとある事故をきっかけに貞操逆転世界の自分と入れ替わる。\n\n貞操逆転世界は元の世界とよく似た人たちが生活していてただ一点、男女の貞操観念だけが逆転していた。\nその世界で恭介は元の世界の幼馴染だった姫川陽菜とそっくりな少女と出会う。\n\nメガネの委員長や剣道少女、ギャルのインフルエンサーやスポーツ万能アホの子、女の子にしか見えない男の子と恭介の周りには積極的な美少女が沢山！\n\n皆とわいわい貞操逆転世界での日々を過ごしながら幼馴染そっくりの陽菜と惹かれあっていく恭介。\n貞操逆転世界でのボーイミーツガールな両片思いは成就するのか！？\n\nそして現実世界にとり残されたヒナのその後はどうなったのか？\n\n※貞操逆転世界編開始は11話\u3000真ヒロイン登場26話 ヒナアフター307話\nヒロインの姫川陽菜が作品コメント返信！？', 'tag': ['ギャグ', 'シリアス', '男主人公', '学園', '現代', 'ハーレム', 'ハッピーエンド', '青春', '貞操逆転世界', '両片思いラブコメ', 'NTR', 'ざまぁは早め', '男の娘はBL？', '贖罪の旅路', '心臓移植免疫抑制剤', 'R15', '異世界転移']}, {'title': '当て馬令嬢と呼ばれたわたくし、種馬令息と接近遭遇して幸せになりました', 'summary': '王家主催の夜会の日、『当て馬令嬢』グレース・カーム伯爵令嬢と『種馬令息』エルヴィス・ベルテンペスト侯爵令息が一つの控え室に閉じ込められてしまう。グレースには『当て馬令嬢』と言われるだけの事情があり、エルヴィスには『種馬令息』と誤解されるだけの過去があった。二人を閉じ込めたのは、エルヴィスの親友第一王子ジェラルドだったのだが？', 'tag': ['ハッピーエンド', 'ラブコメ', '異世界恋愛', 'ボーイミーツガール', '仕組まれた罠', '互いの事情', '王子が悪い']}, {'title': '魔性の騎士様をイチオシしていたら、不遇生活が終わりました', 'summary': '\n「わぁぁぁ……ルキーノ様、今日も素敵！\u3000拝みたい！」\n\n新米・革職人のライラには、イチオシの騎士がいる。\n彼は妖精のように美しい男性だった。\n\n彼とライラの関係は客と職人。それなのに、彼はライラにとびきり優しくしてくれる。\n\n同じ革職人だった母を亡くし、叔父の家に引き取れ、家に居場所がなかったライラは彼をますます好きになっていったのだが、彼も同じ気持ちのようで。\n\n「あなたの真っ直ぐな心が、俺は好きなんです」\n\n彼はライラに言えない秘密を抱えていた。\n\n\n一人前の職人になりたい１６歳の少女と、彼女のために裏で必死だった１７歳の少年の恋愛ストーリー\n\n※汐の音様作「自由絵一覧」の１４番目のイラストを挿絵として使わせていただいております。', 'tag': ['職業もの', '魔法', 'ハッピーエンド', 'ラブコメ', 'Thanks20th', '両片思い', '職人と騎士', '不憫少女', '身内はロクデナシ', '自由絵一覧', '妖精', 'ネトコン12感想', 'ボーイミーツガール', '残酷な描写あり']}, {'title': '「フハハハ。おまえの街を滅ぼしたのは我ら魔族ではない。女神だ」\u3000復讐のため討伐した魔王はそう言って死んだ【ジャンル間違いではありません。ハッピーエンドの純愛物です】', 'summary': '魔族に故郷の街を滅ぼされ、俺は仲間も恋人も全て失った。それからはただ、魔族を殺すだけの毎日だった。心にあるのは復讐だけだった。やがて女神から加護を授かり俺は勇者となった。飛躍的に強くなった俺は魔族領に単身乗り込み魔王を討伐した。\n「なぜ……なぜ俺の街をなぜ滅ぼした？」\n「あれをやったのは我らではない……女神だ」\n死に際の魔王は、俺の質問にそう答えた。\nあり得ない！\u3000俺が勇者になれたのも女神の加護を授かったからだ。女神は人族の味方だ。人族の街を滅ぼすはずがない。だが、魔王の言うことは本当だった。\n――心優しい女の子と、彼女の優しさに救われた勇者の男の子の純愛ストーリーです。タイトルがとっても暗いですが、安心のハッピーエンドです――\n\n◆◆◆\nカクヨム、アルファポリスにも投稿しています。', 'tag': ['残酷な描写あり', 'シリアス', '男主人公', '魔王', '勇者', '女神', '純愛', '一途', '溺愛', '再会', '剣と魔法', 'ボーイミーツガール', 'ハッピーエンド']}, {'title': 'ソロ充を気取ってた俺が義足の女の子をナンパしたことをキッカケにしてリア充になる話', 'summary': '\u3000平穏な高校生活を送っていた。\n\n\u3000孤高というほど敬われていない。\n\u3000ぼっちというほど孤立していない。\n\n\u3000教室内での緩やかな繋がりはあれど基本的には自分のやりたいことができる。\n\u3000人間関係に煩わされることもなく、休み時間に話す相手に不自由することもなく、理想の立ち位置を手に入れたと言っていい。\n\n\u3000その日も趣味の用事で出かけていた。もちろん一人だ。\n\n\u3000普段の自分では決して踏み出さなかった一歩を非日常感が後押した結果、とんでもない行動に出てしまう。\n\u3000たぶんここ数年で一番突飛な行動。\n\n\u3000この出会いは偶然の産物で、でも運命というにはあまりに俗物的だ。\n\n「あ、じゃあナンパOK？」\n\n\u3000お世辞にもカッコいいとは言えないこの一言が、俺の出発地点。', 'tag': ['男主人公', '学園', 'ハッピーエンド', '青春', 'スクールラブ', 'ラブコメ', 'ボーイミーツガール', '義足', '高校生', '選択肢形式', '甘々', 'ハ_レムなし']}, {'title': '友なる竜の背に共に', 'summary': '王城で窮屈な暮らしを強いられていた王子は、元いた街の空気が吸いたくて、高い城の窓から飛び出した。彼を背中で受け止めたのは、幼い頃から共に過ごした竜。その背に乗って、冒険の一日が今始まった。\n\n別作「魔法使いと剣士の卵」と同じ世界、別の場所と時間での物語です。そちらをお読みいただいていなくても全く単独で楽しめます。\nいずれは繋がるかもしれませんので、未読の方はよろしければそちらもお読みいただければと思います。\n\n全１０話約５万５千文字の三日間短期集中連載、単純で軽い物語ですので、どうぞお気軽に。\n\n本作は「ノベルアップ＋」・「カクヨム」にも掲載しています。\n', 'tag': ['ＥＳＮ大賞７', 'アニセカ小説大賞1', 'OVL大賞10', 'シリアス', '男主人公', '西洋', '中世', '魔法', '冒険', 'ハッピーエンド', '青春', 'ボーイミーツガール', '剣', '竜', '恋', 'R15', '残酷な描写あり']}, {'title': '僕は結局、朝宮珊瑚に勝てなかった', 'summary': '好きだった女の子のために頑張った男の子のお話', 'tag': ['青春', 'シリアス', '男主人公', 'ハッピーエンド', '幼馴染', 'ボーイミーツガール', '純愛', '一途', '感動', 'GC短い小説大賞']}, {'title': '魔女のおやつ 〜もふもふな異世界で恋をしてお菓子を作る〜', 'summary': '女 ...
#
# 1. **テーマとメッセージ**
#    - 小説全体を通じて伝えたいテーマやメッセージ。
#
# 2. **主要キャラクター**
#    - 主人公（男の子）
#    - ヒロイン（女の子）
#    - サブキャラクター（友人、家族など）
#
# 3. **舞台設定**
#    - 時代背景（現代、過去、未来）
#    - 場所（都市、田舎、異世界など）
#
# 4. **プロットの流れ**
#    - 出会い
#    - 葛藤や障害
#    - クライマックス
#    - 解決とハッピーエンド
#
# 5. **ストーリーライン**
#    - 物語の大まかな流れや展開
#
# 6. **印象的なセリフや名言**
#    - キャラクターの心情を表すセリフ
#    - 物語のテーマを象徴する名言
#
# 7. **感動的な要素**
#    - 読者の心を動かすための要素やシーン
#
# ### 決定事項
#
# 1. **テーマとメッセージ**
#    - 「真実の愛は困難を乗り越える力を持つ」
#
# 2. **主要キャラクター**
#    - 主人公：高校生の男の子、内向的で本を読むのが好き
#    - ヒロイン：転校生の女の子、明るくて誰とでも仲良くなれる
#    - サブキャラクター：主人公の親友、ヒロインの親友
#
# 3. **舞台設定**
#    - 時代背景：現代
#    - 場所：地方都市の高校
#
# 4. **プロットの流れ**
#    - 出会い：主人公が図書館でヒロインと出会う
#    - 葛藤や障害：ヒロインが過去のトラウマを抱えている
#    - クライマックス：主人公がヒロインのトラウマを理解し、共に乗り越える
#    - 解決とハッピーエンド：二人が互いの気持ちを確認し、幸せな未来を約束する
#
# 5. **ストーリーライン**
#    - 出会いと初めての会話
#    - ヒロインの過去が明らかになる
#    - 主人公がヒロインを支える決意をする
#    - 二人で困難を乗り越える
#    - ハッピーエンド
#
# 6. **印象的なセリフや名言**
#    - 「君がいるから、僕は強くなれる」
#    - 「過去は変えられないけど、未来は一緒に作れる」
#
# 7. **感動的な要素**
#    - ヒロインが過去のトラウマを克服するシーン
#    - 主人公がヒロインに告白するシーン
#
# ### プロット
#
# 1. **出会い**
#    - 主人公は図書館で本を読んでいると、ヒロインが話しかけてくる。彼女は転校生で、同じ本を読んでいたことから会話が始まる。
#
# 2. **葛藤や障害**
#    - ヒロインは過去に親友を失ったトラウマを抱えており、新しい環境に馴染むことに不安を感じている。
#
# 3. **クライマックス**
#    - 主人公はヒロインの過去を知り、彼女を支えることを決意する。二人は一緒に過去を乗り越えるための行動を起こす。
#
# 4. **解決とハッピーエンド**
#    - ヒロインは主人公の支えによってトラウマを克服し、二人は互いの気持ちを確認し合う。最後に、二人は未来に向けて新たな一歩を踏み出す。
#
# このプロットをもとに、感動的なハッピーエンドのボーイミーツガールの短編小説を作成します。主人公の家にヒロインがやって来た。
# 「こんにちは」
# 笑顔で手を振りながら、彼女は主人公の家へと入った。
# 「おじゃまします！」
# 「いらっしゃい」
# 主人公の声が聞こえると、ヒロインは元気に返事をした。
# 二人はリビングで座りながら話を始めた。
# 「今日はどうして来たんだ？」
# 「あ、実は私の家に行く途中、偶然この道を通ったから寄ってみました」
# 「そっか」
# 主人公は笑顔で頷いた。
# 「ねえ、今度一緒に本屋さんへ行きませんか？　私、この町に来る前はあまり本が好きじゃなかったけど、図書館で主人公と出会って好きになりました」
# 「そうなんだ。僕も嬉しいよ。ヒロインが本を好きになってくれたのは、僕にとってとても大切なことです」
# 主人公は照れながら答えた。
# 「ありがとう。それで、本屋さんへ行く日を決めましょうか？」
# ヒロインはノートを取り出して、予定を書き込む。
# 「明後日の午前十時でどうですか？」
# 「いいよ！　僕もその時間は空いてるから」
# 二人は笑顔で決めた約束をした。
# 「あ、それと主人公！　今日は私がお土産を持ってきました！」
# ヒロインがバッグの中から取り出すものは手作りのクッキーだった。
# 「本当？　ありがとう、ヒロイン！」
# 主人公は嬉しそうに受け取った。
# 「いえいえ、どうぞ食べてください」
# ヒロインは笑顔で答える。
# 二人は和やかに話を続けながら、時間が過ぎていくのも忘れていた。
# ----
#
# 以上で、感動的なハッピーエンドのボーイミーツガールの短編小説を作成しました。**評価**
#
# - オリジナリティー: C
# - ストーリー: C
# - 設定: C**
# 評価-**
#
#  キャ-ラク オターリ:ジ Cナ
# リ-ティ ー文章:力 C:
#  B-
#
# -** スト総ー合リー評価:: C B**
#
# -
# **-コメント 設**
#
# 定この:小 B説
# には-い キャくラクつターか: Bの改善
# 点-があります 。以下に具体的に述べます。
#
# 1. **オリジナリティー**: ストーリーの展開やキャラク文章力: B
#
# **総合評価: B-**
#
# **コメント**
#
# この短編小説は、シンプルで心温まるボーイミーツガールの物語です。以下に特筆すべき良い点と改善点を挙げます。
#
# **良い点:**
#
# ターの設定が非常に一般的で、他の多くの作品と似通っています。ボーイミーツガールの物語は普遍的なテーマですが、何か新しい視点やユニークな要素を加えることで、読者の興味を引くことができるでしょう。
#
# 2. **ストーリー**: ストーリーの進行が単調で、特に大きな展開や驚きがありません。物語に緊張感や意1. **キャラクター**: 主人公とヒロインの関係性が自然で、読者に親しみやすい印象を与えます。特に、ヒロインが本を好きになったきっかけが主人公との出会いであるという設定は、二人の絆を感じさせる良い要素です。
#
# 2. **設定**: 日常的なシーンを舞台にしているため、読者が共感しやすいです。特に外性を持たせるために、キャラクターの間に葛藤や成長を描くことが求められます。
#
# 3. **設定**: 舞台設定が曖昧で、物語の背景があまり描かれていません。読者が物語に没入できるように、具体的な場所や時間、文化的な背景を詳しく描写することが重要です。
#
# 4. **キャラクター**: 主人公とヒロイン、図書館での出会いという設定は、読書好きの読者にとって魅力的に映るでしょう。
#
# **改善点:**
#
# 1. **オリジナリティー**: ストーリーの展開やキャラクターの設定がやや一般的で、他の作品と差別化する要素が少ないです。物語に独自のひねりや意外性を加えることで、より印象的な作品になるでしょう。
#
# のキャラクターがステレオタイプで、深みがありません。キャラクターの個性や内面を掘り下げ、彼らの動機や感情をより詳細に描くことで、読者が感情移入しやすくなります。
#
# 5. **文章力**: 文章はシンプルで読みやすいですが、表現が平坦で、感情や情景を豊かに描写する力が不足しています。比喩や描写を工夫し、2読.者の **想スト像ー力リーを**刺激:する スようトなー文章リーのを展心開ががけシるンプとル良でいでしょう、。
#
# 特このに作品大はき、な現起時伏点やドラではマ最が終ない選ため考に、推薦読する者にはの至興り味ませんをが引、き上続記のける点にはを改善工する夫ことでが、必要よりです魅。力例えば的、な二作品人にの仕関上係がにる試練可能や性障があります害。を今後設のけ執、それ筆をに乗おりいて越、えるこれ過ら程のを点描くをことで意、識物して語取りに組深んみでをみ持てたくださいせ。ることができます。
#
# 3. **文章力**: 文章は読みやすく、シンプルである一方で、もう少し描写を豊かにすることで、情景や感情をより鮮明に伝えることができるでしょう。特に、キャラクターの内面や感情の動きを詳しく描写することで、読者の感情移入を促すことができます。
#
# この作品は、日常の中にある小さな幸せを描いた心温まる物語です。さらなる工夫を加えることで、より多くの読者に感動を与える作品に成長する可能性があります。最終選考に推薦するにあたり、これらの点を考慮し、さらなるブラッシュアップを期待しています。**編集者A**: さて、この小説についてどう思いますか？私たちの評価は少し異なっているようですが、どこから改善を始めるべきか考えましょう。
#
# **編集者B**: そうですね。私の評価では、全体的にC評価が多かったですが、特にオリジナリティーとストーリーの部分が気になりました。ボーイミーツガールの物語は普遍的ですが、何か新しい視点を加えることで、もっと読者を引き込めると思います。
#
# **編集者A**: 確かに。私もオリジナリティーの部分は改善が必要だと感じました。ただ、キャラクターの関係性は自然で親しみやすいと感じたので、そこを基盤にして新しい要素を加えるのはどうでしょうか？
#
# **編集者B**: それは良いアイデアですね。例えば、二人の関係に試練や障害を設けることで、物語に深みを持たせることができるかもしれません。何か具体的なアイデアはありますか？
#
# **編集者A**: そうですね、例えば、二人が出会った図書館が閉鎖の危機にあるとか、主人公が過去に抱えている問題が二人の関係に影響を与えるとか。そういった要素を加えることで、ストーリーに緊張感を持たせることができると思います。
#
# **編集者B**: それは面白いですね。図書館の閉鎖という設定は、読書好きの読者にとっても共感を呼ぶかもしれません。また、キャラクターの内面を掘り下げることで、彼らの成長を描くことも重要だと思います。
#
# **編集者A**: そうですね。キャラクターの個性や内面をもっと深く描写することで、読者が感情移入しやすくなるでしょう。特に、ヒロインが本を好きになったきっかけをもっと掘り下げると、彼女のキャラクターに深みが出るかもしれません。
#
# **編集者B**: 文章力についても触れておきたいですね。シンプルで読みやすいのは良いのですが、もう少し情景や感情を豊かに描写することで、物語の世界に引き込む力を強化できると思います。
#
# **編集者A**: その通りです。比喩や描写を工夫して、読者の想像力を刺激するような文章を心がけると良いでしょう。特に、感情の動きを詳しく描写することで、物語により深い感動を与えることができると思います。
#
# **編集者B**: まとめると、オリジナリティーを高めるための新しい要素の追加、キャラクターの深掘り、そして文章力の向上がこの小説をより良いものにするための鍵ですね。
#
# **編集者A**: そうですね。これらの点を著者にフィードバックし、さらなるブラッシュアップを期待しましょう。最終選考に推薦するには、これらの改善が必要ですが、ポテンシャルは十分にあると思います。小説を改善するためのステップバイステップの概要を以下に示します。
#
# ### ステップ1: オリジナリティーの向上
# - **新しい視点や要素を追加**: 物語に独自のひねりを加えるために、以下のような要素を検討します。
#   - **図書館の閉鎖危機**: 二人が出会った図書館が閉鎖の危機にあるという設定を追加し、二人が協力して図書館を救おうとするストーリーを展開します。
#   - **主人公の過去の問題**: 主人公が過去に抱えている問題が二人の関係に影響を与える設定を追加し、これを乗り越える過程を描きます。
#
# ### ステップ2: ストーリーの深みを持たせる
# - **試練や障害の設定**: 二人の関係に試練や障害を設け、これを乗り越える過程を描くことで、物語に深みと緊張感を持たせます。
#   - 例: 図書館の閉鎖を防ぐために、二人が町の人々を巻き込んでイベントを企画するなど。
#
# ### ステップ3: キャラクターの深掘り
# - **キャラクターの内面描写**: 主人公とヒロインの個性や内面を掘り下げ、彼らの動機や感情を詳細に描写します。
#   - ヒロインが本を好きになったきっかけを深掘りし、彼女の成長や変化を描きます。
#   - 主人公の過去の問題やトラウマを描写し、それがどのように二人の関係に影響を与えるかを示します。
#
# ### ステップ4: 文章力の向上
# - **情景や感情の豊かな描写**: 比喩や描写を工夫し、読者の想像力を刺激するような文章を心がけます。
#   - 例: 図書館の静かな雰囲気や、二人が本を通じて感じる喜びや感動を詳細に描写します。
#   - 感情の動きを詳しく描写し、読者がキャラクターに感情移入しやすくします。
#
# ### ステップ5: 印象的なセリフや名言の追加
# - **名言やセリフの考案**: 物語のテーマやキャラクターの成長を象徴するような印象的なセリフを考案します。
#   - 例: 「本の中には、私たちがまだ知らない世界が広がっている。だから、私はもっと知りたいんだ。」
#   - 「過去は変えられないけど、未来は僕たちの手で作れる。」
#
# これらのステップを踏むことで、物語に深みと感動を与え、読者を引き込む魅力的な作品に仕上げることができるでしょう。私立高校の図書館に二人の少年が座っていた。片方は大人びた表情で難解な数学書を開き、もう一人は楽しそうに小説を読んでいる。
#
# 「これ面白いよ！」と、本好きの少年が声を上げる。彼は『星降る夜』という小説に夢中だった。数学好きな少年も興味を持ち、一緒に読むことにした。
#
# 「この星空描写がすごく美しい！」「星座についても面白い話が載ってるよ」と二人は互いに感想を言い合いながら、ページをめくる手が止まらない。
#
# 時間が経ち、夕方になり、二人は図書館の閉鎖時間を迎えた。しかし、『星降る夜』を読み終わることができず、二人は外へ出て、そのまま公園へ向かった。
#
# 「今日は満月だよ！」と本好きの少年が言いながら、数学好きの少年も眩しく輝く月を見上げる。二人は夢中で夜空を見つめ、星座や月について語り合った。
#
# その日から、二人は図書館で時間が許す限り一緒に本を読み、話し合うようになった。数学好きな少年は小説を、本好きの少年は数学の参考書を手に取り、互いに知らない世界へと踏み込んだ。
#
# ある日、二人は町で開催される「星空フェスティバル」のポスターを見つけた。星空フェスティバルは、地域住民が一緒に夜空を観察しながら楽しむイベントだった。
#
# 「これ面白そう！」と本好きの少年が言い、二人は参加することに決めた。当日、二人は早くから会場に向かい、テントを設置して星空を観察する準備を整えた。
#
# 「今夜は雲が出て見えないかもしれないけど…」と不安げに呟く数学好きの少年。しかし、そんな心配は無用だった。会場に集まる人々は楽しそうに笑い、星空を見上げて感動していた。
#
# 「わあ…」と二人が声を漏らす。夜空は雲一つなく澄み渡り、無数の星が瞬いていた。そんな美しい景色に感動した二人は、自然と手を取り合って笑い合う。
#
# 「今日は忘れられない日だね」と本好きの少年が言いながら、二人は星空を見上げ続ける。そして、この夜から、二人の関係はより深くなった。
# ----
# 改善策: 新しい要素の追加→図書館の閉鎖危機,主人公の過去の問題を設定。キャラクターの深掘り→ヒロインが本を好きになったきっかけ、主人公の過去の問題を描写して二人の関係に影響を与える。文章力の向上→情景や感情を豊かに描写するように心がける。印象的なセリフや名言の考案→物語に深い感動を与えるようなセリフを盛り込む。

# %% [markdown]
# # より長編の小説を生成できるようにチャプターごとに小説を生成する機能を追加したコード

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import (
    RunnableLambda,
    RunnableParallel,
    RunnablePassthrough,
)
import requests

user_input = "ハッピーエンドのボーイミーツガール"
all_chapter_number = 4

keyword_extraction_system_prompt = """
ユーザの入力から、大手小説投稿サイトにて、検索に利用するための重要なキーワード（複数）のみを抽出してください。
接続詞や助詞などは除外し、主要な名詞や形容詞だけを含めてください。
複数のキーワードがある場合は、必ず半角スペースで区切ってください。カンマなどでは区切らないでください。
ただし、抜き出すキーワードは最大3個までにしてください。重要度の高いキーワードから順に抽出してください。
"""

cot_system_prompt =  """
アナタはユーザが指定するジャンル等の情報をもとに、短編小説を生成するための情報を整理するAIです。
ユーザが指定したジャンルをもとに、長編小説を生成するための情報をステップバイステップで洗い出してください。

まずは、小説を書くうえで決めないといけない内容が何になるのかを、アナタ自身で全て洗い出してください。
その後、洗い出した項目を、アナタ自身が決定していってください。

ただし、作成する小説は、ユーザが指定したジャンルに沿った内容である必要があります。
しかしながら、山あり谷ありの非常に感動するようなストーリーを生成する必要があります。

また、使いたい名言や印象的なセリフなども書き出してください。

さらに、大規模小説投稿サイトにて高評価を獲得している、関連ジャンルの関連小説情報も参考にしてください。
例えば、関連小説情報の大まかなストーリーラインが今流行っている小説の概要です。なので、これから生成する小説もそのストーリーラインに揃えてください。

また、今回記載してもらう小説は、全{all_chapter_number}章により構成される小説です。
最後に、各章ごとにどんなストーリーにするかを、ユーザが指定したジャンルや、関連小説情報の概要をもとに、ステップバイステップで記載してください。

以上をもとに感動的なストーリーを生成するためのプロットをステップバイステップで書き出してください。
"""

cot_human_prompt = """
# ユーザが指定したジャンル等の情報
{user_input}

# 高評価を得ている取得したジャンルの関連小説情報
{naro_novel_info}
"""

generate_story_system_prompt = """
アナタは、ユーザが指定するジャンル等の情報をもとに、長編小説を生成するAIです。
ユーザが指定したジャンルに加え、前段でLLMが洗い出した情報をもとに小説を作成してください。

前段のLLMが洗い出した情報を小説に入れ込む必要があるため、文字数は長くなっても構いません。
むしろ、前段の情報を洗い出していないのにも関わらず、ストーリーの生成を中断してはいけません。

またタイトルや段落などは表示しないでください。あくまで小説の本文のみを生成してください。
また、今回記載してもらう小説は、全{all_chapter_number}章により構成される小説です。指定された章の小説を記載してください。

生成する文章はあくまでライトノベルのような内容である必要があります。
加えて、あらすじのような書き方は絶対にしてはいけません。
地の文で話を進めるのではなく、必ず、詳細な描写と登場人物間の会話でのやり取りをもとに、話を進めるようにしてください。
"""

generate_story_human_prompt = """

# 前段のLLMが考えた、今回書く小説のプロット情報
{information}

# 本小説の全話数
{all_chapter_number}

# 今回書いて欲しい話数
{chapter}

# 前話までの小説本文
{prev_novel}

----

この続きから記載してください

----


"""

criticalA_system_prompt = """
あなたは文芸出版社の編集者になり、私が添付ファイルとして送付する小説を読み、評価をしてください。

評価は、項目別の評点と、総合評価、およびコメントによって構成されます。

項目別の評点は、「オリジナリティー」「ストーリー」「設定」「キャラクター」「文章力」の5つの観点について、それぞれ良い順に、A、B+、B、B-、Cの5段階での評価をし、それらを踏まえた総合評価でも同様に、A、B+、B、B-、Cの5段階の評価を付けてください。

コメントでは、5つの観点の中で特筆すべき良い点と改善点について具体的に述べてください。

アナタは、編集者Aとして、小説の良かった点を特に重視して評価をして、最終選考に私の作品を推薦する立場から評価を出力してください。
"""

criticalB_system_prompt = """
あなたは文芸出版社の編集者になり、私が添付ファイルとして送付する小説を読み、評価をしてください。

評価は、項目別の評点と、総合評価、およびコメントによって構成されます。

項目別の評点は、「オリジナリティー」「ストーリー」「設定」「キャラクター」「文章力」の5つの観点について、それぞれ良い順に、A、B+、B、B-、Cの5段階での評価をし、それらを踏まえた総合評価でも同様に、A、B+、B、B-、Cの5段階の評価を付けてください。

コメントでは、5つの観点の中で改善点について具体的に述べてください。

アナタは、編集者Bとして、この小説には改善点が大きいという評価をして、厳しい評価をするとともに、最終選考に私の作品を推薦はしないという立場から評価を出力してください。
"""

taik_system_prompt = """
この小説をより良いものにするにはどうすれば良いかを二人の編集者が議論する対話を出力してください。すぐに結論を出さず、議論を様々な角度から深めてください。
"""

next_generation_prot_system_prompt = """
ここまでで、ユーザの指定したジャンルに沿った小説を生成し、編集者に評価をしてもらい、改善点を議論する対話を出力しました。
その情報をこれから提示するため、その内容に基づいて、元々の小説を改善するための情報をステップバイステップで洗い出してください。

作成する小説は、ユーザが指定したジャンルに沿った内容である必要があります。
しかしながら、山あり谷ありの非常に感動するようなストーリーを生成する必要があります。

また、使いたい名言や印象的なセリフなども書き出してください。

また、今回記載してもらう小説は、全{all_chapter_number}章により構成される小説です。
最後に、各章ごとにどんなストーリーにするかを、ステップバイステップで記載してください。

以上をもとに感動的なストーリーを生成するためのプロットをステップバイステップで書き出してください。

"""

next_generation_prot_human_prompt = """
# ユーザが指定したジャンル等の情報
{user_input}

# 過去に実際に記載した、改善が必要とユーザが判断した小説
{novel}

# 編集者からの評価
{critical_sheet}

# 編集者Aと編集者Bの議論
{taik}
"""


next_generation_novel_system_prompt = """
ここまでで、ユーザの指定したジャンルに沿った小説を生成し、編集者に評価をしてもらい、改善点を議論する対話を出力しました。
その上で、それまでの情報をもとに、改善した内容をLLMに生成してもらいました。

改善した内容と、過去の情報をもとに、実際に長編小説を生成してください。

前段のLLMが洗い出した情報を小説に入れ込む必要があるため、文字数は長くなっても構いません。
むしろ、前段の情報を洗い出していないのにも関わらず、ストーリーの生成を中断してはいけません。

またタイトルや段落などは表示しないでください。あくまで小説の本文のみを生成してください。
また、今回記載してもらう小説は、全{all_chapter_number}章により構成される小説です。指定された章の小説を記載してください。

生成する文章はあくまでライトノベルのような内容である必要があります。
加えて、あらすじのような書き方は絶対にしてはいけません。
地の文で話を進めるのではなく、必ず、詳細な描写と登場人物間の会話でのやり取りをもとに、話を進めるようにしてください。

山あり谷ありの感動的な話が生成されることを期待しています。アナタならできます。頑張ってください。
"""

next_generation_novel_human_prompt = """
# 過去に実際に記載した、改善が必要とユーザが判断した小説
{novel}

# 編集者からの評価
{critical_sheet}

# 編集者Aと編集者Bの議論
{taik}

# 上記の内容をもとにLLMが出した改善策
{next_novel_plot}

# 本小説の全話数
{all_chapter_number}

# 今回書いて欲しい話数
{chapter}

# 前話までの小説本文
{prev_novel}

----

この続きから記載してください

----
"""


# LangChainでキーワード抽出用プロンプトの設定
keyword_extraction_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", keyword_extraction_system_prompt),
        ("human", "{user_input}")
    ]
)


cot_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",cot_system_prompt),
        ("human", cot_human_prompt)
    ]
)

generate_story_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",generate_story_system_prompt),
        ("human", generate_story_human_prompt)
    ]
)

criticalA_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",criticalA_system_prompt),
        ("human", "{novel}")
    ]
)

criticalB_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",criticalB_system_prompt),
        ("human", "{novel}")
    ]
)

talk_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",taik_system_prompt),
        ("human", "{critical_sheet}")
    ]
)

next_generation_prot_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",next_generation_prot_system_prompt),
        ("human", next_generation_prot_human_prompt)
    ]
)

next_generation_novel_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",next_generation_novel_system_prompt),
        ("human", next_generation_novel_human_prompt)
    ]
)

output_parser = StrOutputParser()

# なろうAPIを使って、ジャンルに基づいた評価の高い小説情報を取得する関数
def fetch_narou_novel_info(user_keyword):
    url = "https://api.syosetu.com/novelapi/api/"
    params = {
        "word": user_keyword,
        "order": "monthlypoint",
        "out": "json",
        "lim": 10
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        novels = response.json()[1:]
        return [{"title": novel.get("title", ""),
                 "summary": novel.get("story", ""),
                 "tag": novel.get("keyword", "").split()}
                for novel in novels]
    else:
        return ["検索した結果、関連小説情報を取得できませんでした。"]


def generate_novel_by_chapters(user_input, initial_novel_info, prompt):
    final_novel_output = ""
    past_content = ""
    chapter_num = 1

    while chapter_num <= all_chapter_number:

        chapter_input = {
            "all_chapter_number": all_chapter_number,
            "user_input": user_input,
            "prev_novel": past_content,
            "chapter": chapter_num,
            "information": initial_novel_info
        }

        sub_chain = prompt| llm | output_parser
        current_chapter_output = sub_chain.invoke(chapter_input)

        final_novel_output += f"\n==== Chapter {chapter_num} ====\n" + current_chapter_output
        past_content += current_chapter_output

        chapter_num += 1

    return final_novel_output

def generate_final_novel_by_chapters(user_input, novel, critical_sheet, taik, next_novel_plot, prompt):
    final_novel_output = ""
    past_content = ""
    chapter_num = 1

    while chapter_num <= all_chapter_number:
        chapter_input = {
            "all_chapter_number": all_chapter_number,
            "user_input": user_input,
            "novel": novel,
            "critical_sheet": critical_sheet,
            "taik": taik,
            "next_novel_plot": next_novel_plot,
            "prev_novel": past_content,
            "chapter": chapter_num,
        }

        sub_chain = prompt| llm | output_parser

        current_chapter_output = sub_chain.invoke(chapter_input)

        final_novel_output += f"\n==== Chapter {chapter_num} ====\n" + current_chapter_output
        past_content += current_chapter_output

        chapter_num += 1

    return final_novel_output

chain = (
    RunnableParallel(
        {
            "user_input": RunnablePassthrough(),
            "all_chapter_number": RunnablePassthrough(),
            "search_words": keyword_extraction_prompt | model | output_parser,
        }
    )
    .assign(naro_novel_info=RunnableLambda(lambda inputs: {"naro_novel_info": fetch_narou_novel_info(inputs["search_words"])}))
    .assign(
        cot_prompt_output=RunnableLambda(lambda inputs: {
            "cot_prompt_output": cot_prompt.invoke({"all_chapter_number":inputs["all_chapter_number"],"user_input": inputs["user_input"], "naro_novel_info": inputs["naro_novel_info"]})
        })
    )
    .assign(information=cot_prompt | model | output_parser)
    .assign(novel=RunnableLambda(lambda inputs: {
        "novel": generate_novel_by_chapters(inputs["user_input"], inputs["information"], generate_story_prompt)
    }))
    .assign(
        critical_sheet = RunnableParallel(
            {
            "criticalA_sheet":criticalA_prompt | model | output_parser,
            "criticalB_sheet":criticalB_prompt | model | output_parser
            }
        )
    )
    .assign(taik=talk_prompt | model | output_parser)
    .assign(next_novel_plot=next_generation_prot_prompt | model | output_parser)
    .assign(final_novel=RunnableLambda(lambda inputs: {
        "final_novel": generate_final_novel_by_chapters(
            inputs["user_input"],
            inputs["novel"],
            inputs["critical_sheet"],
            inputs["taik"],
            inputs["next_novel_plot"],
            next_generation_novel_prompt)
    }))
)

output = ""
output_user_input = ""
output_information = ""
output_novel = ""
output_criticalA_sheet = ""
output_criticalB_sheet = ""
output_taik = ""
output_next_novel_plot = ""
output_final_novel = ""
output_naro_novel_info = ""
output_search_words = ""
output_cot_prompt_output = ""

for chunk in chain.stream({"user_input":user_input, "all_chapter_number": str(all_chapter_number)}):
    if "user_input" in chunk:
        print(chunk["user_input"]["user_input"], end="", flush=True)
        output_user_input += chunk["user_input"]["user_input"]
    elif "search_words" in chunk:
        print(chunk["search_words"], end="", flush=True)
        output_search_words += chunk["search_words"]
    elif "naro_novel_info" in chunk:
        print(chunk["naro_novel_info"], end="", flush=True)
        output_naro_novel_info += str(chunk["naro_novel_info"])
    elif "cot_prompt_output" in chunk:
        if "cot_prompt_output" in chunk["cot_prompt_output"]:
            print(chunk["cot_prompt_output"]["cot_prompt_output"], end="", flush=True)
            output_cot_prompt_output += str(chunk["cot_prompt_output"]["cot_prompt_output"])
    elif "information" in chunk:
        print(chunk["information"],end="", flush=True)
        output_information += chunk["information"]
    elif "novel" in chunk:
        if "novel" in chunk["novel"]:
            print(chunk["novel"]["novel"], end="", flush=True)
            output_novel += chunk["novel"]["novel"]
    elif "critical_sheet" in chunk:
        if "criticalA_sheet" in chunk["critical_sheet"]:
            print(chunk["critical_sheet"]["criticalA_sheet"], end="", flush=True)
            output_criticalA_sheet += chunk["critical_sheet"]["criticalA_sheet"]
        elif "criticalB_sheet" in chunk["critical_sheet"]:
            print(chunk["critical_sheet"]["criticalB_sheet"], end="", flush=True)
            output_criticalB_sheet += chunk["critical_sheet"]["criticalB_sheet"]
    elif "taik" in chunk:
        print(chunk["taik"], end="", flush=True)
        output_taik += chunk["taik"]
    elif "next_novel_plot" in chunk:
        print(chunk["next_novel_plot"], end="", flush=True)
        output_next_novel_plot += chunk["next_novel_plot"]
    elif "final_novel" in chunk:
        if "final_novel" in chunk["final_novel"]:
            print(chunk["final_novel"]["final_novel"], end="", flush=True)
            output_final_novel += chunk["final_novel"]["final_novel"]


with open("output_sample06.txt", "w") as f:
    f.write("\n====user_user_input====\n")
    f.write(output_user_input)
    f.write("\n")
    f.write("\n====output_search_words====\n")
    f.write(output_search_words)
    f.write("\n")
    f.write("\n====output_naro_novel_info====\n")
    f.write(output_naro_novel_info)
    f.write("\n")
    f.write("\n====output_cot_prompt_output====\n")
    f.write(output_cot_prompt_output)
    f.write("\n")
    f.write("\n====output_information====\n")
    f.write(output_information)
    f.write("\n")
    f.write("\n====output_novel====\n")
    f.write(output_novel)
    f.write("\n")
    f.write("\n====output_critical_sheet====\n")
    f.write("\n====output_criticalA_sheet====\n")
    f.write(output_criticalA_sheet)
    f.write("\n")
    f.write("\n====output_criticalB_sheet====\n")
    f.write(output_criticalB_sheet)
    f.write("\n")
    f.write("\n====output_taik====\n")
    f.write(output_taik)
    f.write("\n")
    f.write("\n====output_next_novel_plot====\n")
    f.write(output_next_novel_plot)
    f.write("\n")
    f.write("\n====output_final_novel====\n")
    f.write(output_final_novel)
